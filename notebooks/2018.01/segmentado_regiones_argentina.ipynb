# %%
import re
from xml.etree import ElementTree

def getPolygonsFromSvgPathD(d, scale=1, translate=[0, 0]):
    subpolygons = []
    points = []
    relseq = True
    current_bezier = 0
    # https://developer.mozilla.org/es/docs/Web/SVG/Attribute/d
    for p in re.finditer(r'([MmLlVvHhc ]) ?( ?-?\d+\.?\d*)(,-?\d+\.?\d*)?( ?z)?', d):
        if p.group(3):
            newp = [float(p.group(2)), float(p.group(3)[1:])]
        elif p.group(1) in ['H', 'h']:
            newp = [float(p.group(2)), 0]
        elif p.group(1) in ['V', 'v']:
            newp = [0, float(p.group(2))]
        if p.group(1) in ['m'] and len(subpolygons) > 0:
            newp[0] += subpolygons[-1][0][0]
            newp[1] += subpolygons[-1][0][1]
        if p.group(1) in ['M', 'm']:
            points = []
        # blank points may be absolute or relative depending on the last ML/ml rule
        if p.group(1) in ['M', 'L']:
            relseq = False
        if p.group(1) in ['m', 'l']:
            relseq = True
        # ignore cubic bezier controls
        if p.group(1) in ['C', 'c']:
            current_bezier = 3
        # ignore quaratic bezier controls
        if p.group(1) in ['Q', 'q']:
            current_bezier = 4
        if current_bezier > 0:
            current_bezier -= 1
        if current_bezier > 0:
            continue
        if ((p.group(1) in ['l', 'h', 'v']) or (p.group(1) == ' ' and relseq)) and len(points) > 0:
            newp[0] += points[-1][0]
            newp[1] += points[-1][1]
        points.append(np.array(newp))
        if p.group(4): # if z is present
            subpolygons.append(np.array(points))
    return [[point*scale+translate for point in poly] for poly in subpolygons]

# %%
import numpy as np
from matplotlib import cm
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
import matplotlib.pyplot as plt

map_polygons = {}

# https://www.amcharts.com/svg-maps/?map=argentina
provinces = ["Buenos Aires", "Catamarca", "Chaco", "Chubut", "Ciudad de Buenos Aires", "Córdoba", "Corrientes", "Entre Ríos", "Formosa", "Jujuy", "La Pampa", "La Rioja", "Mendoza", "Misiones", "Neuquén", "Río Negro", "Salta", "Santa Cruz", "Santiago del Estero", "Santa Fe", "San Juan", "San Luis", "Tierra del Fuego", "Tucumán"]
svg = ElementTree.parse('../../data/argentinaHigh.svg')
for province in provinces:
    d = svg.find('.//*[@title="%s"]' % province).get('d')
    map_polygons[province] = getPolygonsFromSvgPathD(d, scale=2.5, translate=[0, 0])

svg = ElementTree.parse('../../data/Mapa_de_Buenos_Aires.svg')
d = svg.find('.//*').get('d')
map_polygons['Ciudad Autónoma de Buenos Aires'] = getPolygonsFromSvgPathD(d, scale=0.3, translate=[800, 1000])

svg = ElementTree.parse('../../data/falklandIslandsHigh.svg')
d = svg.find('.//*[@title="%s"]' % 'Falkland Islands').get('d')
map_polygons['Malvinas Argentinas'] = getPolygonsFromSvgPathD(d, scale=0.2, translate=[600, 1700])

# %%
import pandas as pd
import numpy as np
import re
from matplotlib import cm
from functools import reduce
from IPython.display import display, Markdown as md

def getPeriodDF(period, publish_date, csv_path, columns_src, columns_dst, transforms = []):
    # given a csv_path, extract src columns into dst columns by applying a transform function for a certain period name
    df_src = pd.read_csv(csv_path)
    df_dst = pd.DataFrame(columns=['period', 'publish_date']+columns_dst)
    df_dst[columns_dst] = df_src[columns_src]
    df_dst['period'] = period
    df_dst['publish_date'] = pd.to_datetime(publish_date)
    # apply custom transformations
    for transform in transforms:
        df_src, df_dst = transform(df_src, df_dst)
    return df_dst

def transformNormalize(df_src, df_dst):
    # cast to float the salary column, some datasets gets wrongly parsed due to crappy user input
    df_dst['salary'] = df_dst['salary'].astype(float)
    df_dst['age'] = df_dst['age'].astype(str)
    # normalize stack column
    re_separator = ' *, *| *; *| *\. *| *\| *| *\/ *| *- *'
    re_garbage = '"""|\*|nan|='
    df_dst['stack'] = df_dst['stack'].apply(lambda s: re.split(re_separator, re.sub(re_garbage, '', str(s)).strip().lower()))
    # munge the dataset, removing entries that we consider not realistic for our analysis
    munging_mask = (df_dst.salary > 5000) & (df_dst.salary < 300000)
    df_src = df_src.loc[munging_mask]
    df_dst = df_dst.loc[munging_mask]
    return df_src, df_dst

def transformNet2Brute201702(df_src, df_dst):
    # filter wether net or brute income
    mask = np.array(df_src['¿Porcentaje, bruto o neto?'].str.contains('Neto'), dtype = bool)
    net_factor = np.array([1.0] * len(df_dst));
    # scales up net salary into brute, given Argentina's social security contributions
    net_factor[ mask ] = 1/0.83
    df_dst['salary'] = net_factor * df_dst['salary']
    return df_src, df_dst

src_common_cols = [
    'Tengo',
    'Años de experiencia',
    'Años en el puesto actual',
    'Trabajo de',
    'Tecnologías que utilizás',
    'Argentina']

dst_cols = [
    'salary',
    'location',
    'gender',
    'age',
    'yoe',
    'yip',
    'role',
    'stack',
    'province']


df = getPeriodDF('2018.01', '2018-03-01', '../../data/2018.01/argentina.csv', 
                  ['Salario mensual (en tu moneda local)', 'Argentina', 'Me identifico'] + src_common_cols, dst_cols, 
                  [transformNormalize, transformNet2Brute201702])


# extract the list of genders
genders = df.gender.unique()

# extract the list of yoes
yoes = df.yoe.unique()

display(md('## Géneros censandos en los datasets'))
[display(md('- %s (%d total)' % (g, len(df.query('gender == "%s"' % g))))) for g in genders]

# define arbitrary ranges for seniority
yoes_jr = ['1 - 2', 'Menos de un año', '1', '2', '3']
yoes_ssr = ['3 - 5', '3', '4', '5', '6']
yoes_sr = ['5 - 7', '8 - 10', '5', '6', '7', '8', '9', '10', '10+']

yoes_ranges = [yoes_jr, yoes_ssr, yoes_sr]
yoes_ranges_names = ['Juniors', 'Semi-Seniors', 'Seniors']

display(md(
    ''.join([
        '$C_{%s} = \large\{\small%s\large\}$\n\n' % (name, ', \ '.join(yoes_ranges[i]))
        for i, name in enumerate(yoes_ranges_names)
    ])
)) 

def mapRegionToSysarmyRegion(p):
    if p == 'Buenos Aires':
        return ['GBA', 'Provincia de Buenos Aires']
    if p == 'Ciudad de Buenos Aires':
        return ['Ciudad Autónoma de Buenos Aires']
    return [p]
# Out:
# ## Géneros censandos en los datasets
# - Hombre (3593 total)
# - Mujer (557 total)
# - Otros (14 total)
# $C_{Juniors} = \large\{\small1 - 2, \ Menos de un año, \ 1, \ 2, \ 3\large\}$
#
# $C_{Semi-Seniors} = \large\{\small3 - 5, \ 3, \ 4, \ 5, \ 6\large\}$
#
# $C_{Seniors} = \large\{\small5 - 7, \ 8 - 10, \ 5, \ 6, \ 7, \ 8, \ 9, \ 10, \ 10+\large\}$

# %%
dfq = df.groupby('province').agg({'province':{'n': len}})
dfq.columns = dfq.columns.droplevel()
dfq = dfq.sort_values(by='n', ascending=True)

dfq['n'].tolist()
dfq.T.columns.tolist()
# Out:
# ['Santa Cruz',
#  'Catamarca',
#  'Tierra del Fuego',
#  'Formosa',
#  'San Juan',
#  'La Rioja',
#  'Santiago del Estero',
#  'La Pampa',
#  'Jujuy',
#  'Corrientes',
#  'San Luis',
#  'Misiones',
#  'Salta',
#  'Chubut',
#  'Entre Ríos',
#  'Río Negro',
#  'Tucumán',
#  'Chaco',
#  'Neuquén',
#  'Mendoza',
#  'Santa Fe',
#  'Córdoba',
#  'GBA',
#  'Provincia de Buenos Aires',
#  'Ciudad Autónoma de Buenos Aires']

# %%
from math import log

plt.rcParams.update({'figure.figsize': (8, 4), 'font.size': 8})
fig, ax = plt.subplots(1, 2)

plt.suptitle('Nivel de participación en la República Argentina', fontsize=10)
index = np.arange(len(dfq))
bar_width = 0.75

ax[0].barh(index, dfq['n'].tolist(), bar_width, alpha=0.8, color='#3e8ec4', lw=0)
ax[0].set_yticklabels(dfq.T.columns.tolist())
ax[0].set_xlabel('Cantidad de respuestas\nen escala lineal')

ax[1].barh(index, list(map(log, dfq['n'].tolist())), bar_width, alpha=0.8, color='#3e8ec4', lw=0)
ax[1].set_yticklabels([])
ax[1].set_xlabel('Cantidad de respuestas\nen escala logarítmica')


for i in range(2):
    ax[i].set_yticks(index + bar_width / 2)
    ax[i].set_frame_on(False)
    ax[i].margins(0, 0)
    ax[i].tick_params(top=False, left=False, right=False)
    ax[i].legend()

plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
from math import log
plt.rcParams.update({'figure.figsize': (0.7*6.5, 0.7*10.0), 'font.size': 8})
fig, ax = plt.subplots()

#plt.suptitle('Nivel de participación por región de la República Argentina', fontsize=10)
patches = []
colors = []
for region in map_polygons:
    sysarmyProvince = mapRegionToSysarmyRegion(region)
    dft = df.query('province in @sysarmyProvince')
    color = len(dft)
    for polygon in map_polygons[region]:
        polygon = Polygon(polygon, True)
        patches.append(polygon)
        colors.append(color)
log_colors = [log(c) if c > 0 else 0 for c in colors]
colormap = plt.get_cmap('Blues', len(colors))
p = PatchCollection(patches, cmap=colormap, alpha=1, lw=0)
ax.add_collection(p)
ax.axis([0, 0.8*2000, 2000+100, -200])
ax.set_axis_off()
ax.margins(0.9, 0.9)
p.set_array(np.array(log_colors))
cbar = fig.colorbar(p, ax=ax, orientation='horizontal', 
            shrink=0.8, aspect=20, fraction=0.1, pad=0.02, format='%1i', ticks=log_colors)
cbar.ax.set_xticklabels([
    color if i in [0, round(len(colors)*0.25), round(len(colors)*0.75), len(colors)] else ''
        for i, color in enumerate(colors)])
cbar.outline.set_visible(False)
#ax.set_title('($n$ tamaño de la muestra, presentado en escala logarítimica)')
ax.set_title('Nivel de participación\npor región de la República Argentina')

#%config InlineBackend.figure_format = 'svg'
#plt.savefig("regiones-muestra.svg")
plt.show()

# %%
from math import log
plt.rcParams.update({'figure.figsize': (len(yoes_ranges)*4.0, len(genders)*6.0), 'font.size': 8})
fig, ax = plt.subplots(len(yoes_ranges), len(genders))

plt.suptitle('Nivel de participación por seniority, género y región\nde la República Argentina', fontsize=12)
for i, yoe_range in enumerate(yoes_ranges):
    for j, gender in enumerate(genders):
        patches = []
        colors = []
        for region in map_polygons:
            sysarmyProvince = mapRegionToSysarmyRegion(region)
            dft = df.query('gender == @gender & yoe in @yoe_range & province in @sysarmyProvince')
            color = len(dft)
            for polygon in map_polygons[region]:
                polygon = Polygon(polygon, True)
                patches.append(polygon)
                colors.append(color)
        log_colors = [log(c) if c > 0 else 0 for c in colors]
        colormap = plt.get_cmap('Blues', len(colors))
        p = PatchCollection(patches, cmap=colormap, alpha=1, lw=0)
        ax[i][j].add_collection(p)
        ax[i][j].axis([0, 0.8*2000, 2000+100, -200])
        ax[i][j].set_axis_off()
        ax[i][j].margins(0.9, 0.9)
        p.set_array(np.array(log_colors))
        cbar = fig.colorbar(p, ax=ax[i][j], orientation='horizontal', 
                    shrink=0.8, aspect=20, fraction=0.1, pad=0.02, format='%1i', ticks=log_colors)
        cbar.ax.set_xticklabels([
            color if i in [0, round(len(colors)*0.25), round(len(colors)*0.75), len(colors)] else ''
                for i, color in enumerate(colors)])
        cbar.outline.set_visible(False)
        ax[i][j].set_title('%s %s\n($n$ tamaño de la muestra\nen escala logarítimica)' % (gender, yoes_ranges_names[i]))

plt.show()

# %%
plt.rcParams.update({'figure.figsize': (1.67*len(yoes_ranges)*4.0, 1.67*len(genders)*6.0), 'font.size': 8})
fig, ax = plt.subplots(len(yoes_ranges), len(genders))
plt.suptitle('Rangos de medias salariales por seniority, género y región\nde la República Argentina', fontsize=12)
dfminx = df.salary.min()
dfmaxx = df.salary.mean() + 2*df.salary.std()
for i, yoe_range in enumerate(yoes_ranges):
    for j, gender in enumerate(genders):
        patches = []
        colors = []
        for region in map_polygons:
            sysarmyProvince = mapRegionToSysarmyRegion(region)
            dft = df.query('gender == @gender & yoe in @yoe_range & province in @sysarmyProvince')
            color = dft.salary.mean()/1000
            if len(dft) < 2:
                continue # omit unary samples as not being representative
            for polygon in map_polygons[region]:
                polygon = Polygon(polygon, True)
                patches.append(polygon)
                colors.append(color)
        colors += [dfminx/1000, dfmaxx/1000] # compensate scales across seniority
        colormap = plt.get_cmap('coolwarm_r', int(len(colors)/8)) 
        p = PatchCollection(patches, cmap=colormap, alpha=1, lw=0)
        ax[i][j].add_collection(p)
        ax[i][j].axis([0, 0.8*2000, 2000+100, -200])
        ax[i][j].set_axis_off()
        p.set_array(np.array(colors))
        cbar = fig.colorbar(p, ax=ax[i][j], orientation='horizontal', 
                            shrink=0.8, aspect=20, fraction=0.1, pad=0.02, format='%1i')
        cbar.outline.set_visible(False)
        ax[i][j].set_title('%s %s\n$AR\$/1000\ bruto$' % (gender, yoes_ranges_names[i]))
plt.show()
